# %%
import pandas as pd

df = pd.read_csv("house_prices.csv")
print(df.head())
# Out:
#    Size  Price
# 0    50    150
# 1    60    180
# 2    70    200
# 3    80    220
# 4    90    240

# %%
# First 5 rows of the dataset
print(df.head())

# Last 5 rows of the dataset
print(df.tail())

#Info about the dataset
print(df.info())

#Summary statistics of the dataset
print(df.describe())
# Out:
#    Size  Price
# 0    50    150
# 1    60    180
# 2    70    200
# 3    80    220
# 4    90    240
#    Size  Price
# 5   100    270
# 6   110    300
# 7   120    330
# 8   130    360
# 9   140    400
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Size    10 non-null     int64
#  1   Price   10 non-null     int64
# dtypes: int64(2)
# memory usage: 288.0 bytes
# None
#              Size       Price
# count   10.000000   10.000000
# mean    95.000000  265.000000
# std     30.276504   81.683672
# min     50.000000  150.000000
# 25%     72.500000  205.000000
# 50%     95.000000  255.000000
# 75%    117.500000  322.500000
# max    140.000000  400.000000

# %%
# Select a single column (e.g., "Size")
size_column = df["Size"]
print(size_column)

# Select multiple columns (e.g., "Size" and "Price")
size_price_columns = df[["Size", "Price"]]
print(size_price_columns)
# Out:
# 0     50
# 1     60
# 2     70
# 3     80
# 4     90
# 5    100
# 6    110
# 7    120
# 8    130
# 9    140
# Name: Size, dtype: int64
#    Size  Price
# 0    50    150
# 1    60    180
# 2    70    200
# 3    80    220
# 4    90    240
# 5   100    270
# 6   110    300
# 7   120    330
# 8   130    360
# 9   140    400

# %%
#By index (first 3 rows)
print(df.iloc[0:3])
#By condition
expensive_houses = df[df["Price"] > 500000]
print(expensive_houses)
# Out:
#    Size  Price
# 0    50    150
# 1    60    180
# 2    70    200
# Empty DataFrame
# Columns: [Size, Price]
# Index: []
