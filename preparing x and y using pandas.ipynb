# %%
import pandas as pd

data = {
    "Size":[100, 150, 200, 120, 180],
    "Rooms":[3, 4, 5, 3, 4],
    "Price":[200, 300, 400, 250, 350]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Size  Rooms  Price
# 0   100      3    200
# 1   150      4    300
# 2   200      5    400
# 3   120      3    250
# 4   180      4    350
